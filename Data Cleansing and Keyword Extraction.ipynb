# %%
# Basic functionalities
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
import string
from collections import Counter
import pickle

# options
pd.set_option('max_colwidth',150)

# %%
# Text encoding
from sklearn.feature_extraction import text 
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# Text Processing
from nltk import word_tokenize, pos_tag
import nltk
from nltk.stem.porter import PorterStemmer
porter_stemmer = PorterStemmer()
# nltk.download('wordnet')
# nltk.set_proxy('SYSTEM PROXY')
# nltk.download('punkt')
# nltk.download('averaged_perceptron_tagger')

# %%
# Sentiment analysis
from textblob import TextBlob as tb

# %%
# Topic Modeling
from gensim import matutils, models
from gensim.models import LsiModel
import scipy.sparse
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
# Keyword Extraction
from summa.summarizer import summarize
from summa import keywords

# %%
# Progress bar
from tqdm import tqdm

# %% [markdown]
# # Retrieve Data
#
# ## Data from google drive

# %%
df = pd.read_csv('transcript_paragraph_needed.csv')
df = df[["comedian","transcript"]]
df.columns = ["Comedian","Transcript"]
# get corpus
corpus = df[['Comedian','Transcript']].set_index('Comedian')
corpus
# Out:
#                                                                                                                                                            Transcript
# Comedian
# andy woodhull   she told me she painted some clear cuz it makes her fingernail shiny and she likes them when to be shiny and i support her in that decision i want...
# andy woodhull   we were on a road trip one time and she fell asleep i said honey you got to wake up im sleepy too and we need to talk to me she said i am not asle...
# andy woodhull   i mention my girls already theyre my theyre my stepdaughters im a stepdad stepdad took over the lease on a couple of girls few years back thank yo...
# andy woodhull   coopers you love the old bo you love the old bum forever cuz thats the boat let you know that you enjoy being the captain of a ship but if there w...
# andy woodhull   my girls are teenagers now  and  got a couple teenagers at home and theyre really embracing it and every time i tell people i have teenage daughte...
# ...                                                                                                                                                               ...
# dave chappelle  lets not forget lets not forget ive never met bill cosby so im not defending him lets just remember that he has a valuable legacy that i cant just...
# dave chappelle    ahah ahah     in every ghetto     ahah ahah ahah     in every ghetto     ahah ahah ahah     in every ghetto     ahah ahah ahah     in every ghet...
# dave chappelle    ahah ahah     in every ghetto     ahah     revolution     ahah ahah ahah     in every ghetto  one last thing before you go i just wanted to ackn...
# dave chappelle    can i kick it     yes you can     can i kick it     yes you can     can i kick it     yes you can     well im gone     go on then     can i kick...
# dave chappelle    can i kick it     yes you can     can i kick it     yes you can     can i kick it     yes you can     well im gone     go on then     can i kick...
#
# [2840 rows x 1 columns]

# %% [markdown]
# #### Clean the data

# %%
def apply_data_cleansing(text):
    # Lowercase every words
    text = text.lower()
    # Remove every words with [blah blah blah] format
    text = re.sub('\[.*?\]', '', text)
    # Remove every words with (blah blah blah) format
    text = re.sub('\(.*?\)', '', text)
    # Get rid of the punctuations
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    # Get rid of all the numbers or words that contain numbers
    text = re.sub('\w*\d\w*', '', text)
    # Get rid of these specific punctuations
    text = re.sub('[‘’“”…]', '', text)
    # Get rid of '\n'
    text = re.sub('\n', '', text)
    
    # Tokenizes and lemmetizes (or stems) them
    tokenized = word_tokenize(text)
    stemmed = [porter_stemmer.stem(t) for t in tokenized]
#     lemmetized = [wordnet_lemmatizer.lemmatize(t) for t in tokenized]
    return " ".join(stemmed)

# %%
clean_corpus = pd.DataFrame(corpus.Transcript.apply(apply_data_cleansing))
clean_corpus_index = clean_corpus.reset_index()
clean_corpus_index
# Out:
#             Comedian  \
# 0      andy woodhull
# 1      andy woodhull
# 2      andy woodhull
# 3      andy woodhull
# 4      andy woodhull
# ...              ...
# 2835  dave chappelle
# 2836  dave chappelle
# 2837  dave chappelle
# 2838  dave chappelle
# 2839  dave chappelle
#
#                                                                                                                                                  Transcript
# 0     she told me she paint some clear cuz it make her fingernail shini and she like them when to be shini and i support her in that decis i want them t...
# 1     we were on a road trip one time and she fell asleep i said honey you got to wake up im sleepi too and we need to talk to me she said i am not asle...
# 2     i mention my girl alreadi theyr my theyr my stepdaught im a stepdad stepdad took over the leas on a coupl of girl few year back thank you veri muc...
# 3     cooper you love the old bo you love the old bum forev cuz that the boat let you know that you enjoy be the captain of a ship but if there wa a hur...
# 4     my girl are teenag now and got a coupl teenag at home and theyr realli embrac it and everi time i tell peopl i have teenag daughter at home theyr ...
# ...                                                                                                                                                     ...
# 2835  let not forget let not forget ive never met bill cosbi so im not defend him let just rememb that he ha a valuabl legaci that i cant just throw awa...
# 2836  ahah ahah in everi ghetto ahah ahah ahah in everi ghetto ahah ahah ahah in everi ghetto ahah ahah ahah in everi ghetto wait wait wait wait wait i ...
# 2837  ahah ahah in everi ghetto ahah revolut ahah ahah ahah in everi ghetto one last thing befor you go i just want to acknowledg for the real comedi fa...
# 2838  can i kick it ye you can can i kick it ye you can can i kick it ye you can well im gone go on then can i kick it to my tribe that flow in layer ri...
# 2839  can i kick it ye you can can i kick it ye you can can i kick it ye you can well im gone go on then can i kick it to my tribe that flow in layer ri...
#
# [2840 rows x 2 columns]

# %%
df = pd.DataFrame(clean_corpus_index.Comedian)

# %%
# Pickles the result for later usage
clean_corpus_index.to_pickle('clean_corpus_index.pkl')

# %% [markdown]
# # Analyize the transcripts

# %% [markdown]
# #### Text Encoding

# %%
def dtm(corpus, stop_words='english', pickle_filename="", save_pickle=False):
    cv = CountVectorizer(stop_words=stop_words)
    data_cv = cv.fit_transform(corpus.Transcript)
    data_dtm = pd.DataFrame(data_cv.toarray(), columns=cv.get_feature_names())
    data_dtm.index = corpus.index
    if save_pickle:
        pickle.dump(cv, open(pickle_filename, "wb"))        
    return data_dtm.transpose()

def tf_idf(corpus, stop_words='english', pickle_filename="", save_pickle=False):
    vectorizer = TfidfVectorizer(stop_words='english')
    data_v = vectorizer.fit_transform(corpus.Transcript)
    data_tfidf = pd.DataFrame(data_v.toarray(), columns=vectorizer.get_feature_names())
    data_tfidf.index = corpus.index
    if save_pickle:
        pickle.dump(vectorizer, open(pickle_filename, "wb"))        
    return data_tfidf.transpose()

# %% [markdown]
# #### Top words

# %%
def get_top_words(matrix_dataframe, number_of_words = 30):
    top_dict = {}
    for c in matrix_dataframe.columns:
        top = matrix_dataframe[c].sort_values(ascending=False).head(number_of_words)
        top_dict[c]= list(zip(top.index, top.values))
    return top_dict

# %%
# Get all kinds of corpus
clean_corpus = pd.read_pickle('clean_corpus_index.pkl')

all_corpuses = [clean_corpus]

# %%
df_dtms = []
dtm_tops = []
for corpus in all_corpuses:
    # Document-Term Matrix
    df_dtm = dtm(corpus)
    # Get top words
    dtm_top = get_top_words(df_dtm)
    
    df_dtms.append(df_dtm)
    dtm_tops.append(dtm_top)

# %% [markdown]
# Since there are too many words that are common among all the transcript, we need to add them to the stop-word list and redo the text encoding again.

# %% [markdown]
# #### Extract all common words among the transcript

# %%
commons = []
for c in df.columns:
    words = []
    for r in df[c]:
        top = [word for word in r]
        for t in top:
            words.append(t)    
    commons.append(Counter(words).most_common())

# %%
common_words_list = []
for common in commons:
    new = [word for word, count in common if count > 6]
    common_words_list.append(np.array(new))
common_words_list
# Out:
# [array(['e', ' ', 'a', 'r', 'i', 'n', 'l', 's', 'o', 'h', 'c', 'm', 't',
#         'd', 'y', 'j', 'g', 'p', 'u', 'b', 'f', 'k', 'v', 'w', 'z', '.',
#         '’'], dtype='<U1')]

# %%
pickle.dump(common_words_list, open('common_words_list_index.pkl', 'wb'))

# %% [markdown]
# # Keyword Extraction

# %%
clean_corpus = pd.read_pickle('clean_corpus_index.pkl')

# %%
def merge_transcripts(df, filename):
    """
    :param df: transcript/comedians dataframe.
    :param filename: the csv file to save for the comedian/keywords data
    """
    merged_df = df.groupby('Comedian').agg(lambda t: " ".join(t))
    r_df = pd.DataFrame(columns=['Comedian','Keywords'])
    for c in tqdm(merged_df.index, desc="Extracting..."):
        text = merged_df.loc[c][0]
        kw = keywords.keywords(text)
        r_df = r_df.append({'Comedian': c, "Keywords":", ".join(kw.split('\n'))}, ignore_index=True)
    r_df.to_excel(filename)       
    return r_df

# %%
common_words_list = pickle.load(open('common_words_list_index.pkl', 'rb'))
# Additional stop words
common_words_list.append(np.array(['im','youre','theyre','we','hes','shes','yeah','uh','ill','hell',
                          'shell','theyll','well']))
common_words_list.append(np.array([i for i in 'qwertyuiopasdfghjklzxcvbnm']))

# %%
stop_words_list = []
for common_words in common_words_list:
    stop_words = text.ENGLISH_STOP_WORDS.union(common_words)
    stop_words_list.extend(list(stop_words))

# %%
def remove_stopwords(text):    
    # split the text
    wd = text.split(' ')
    # remove stop words
    resultwords  = [word for word in wd if word.lower() not in stop_words_list]
    return' '.join(resultwords)

# %%
clean_corpus.index = clean_corpus.Comedian
clean_corpus = pd.DataFrame(clean_corpus.Transcript.apply(remove_stopwords))

# %%
clean_corpus.reset_index()
# Out:
#             Comedian  \
# 0      andy woodhull
# 1      andy woodhull
# 2      andy woodhull
# 3      andy woodhull
# 4      andy woodhull
# ...              ...
# 2835  dave chappelle
# 2836  dave chappelle
# 2837  dave chappelle
# 2838  dave chappelle
# 2839  dave chappelle
#
#                                                                                                                                                  Transcript
# 0     told paint clear cuz make fingernail shini like shini support decis want shini just feel like achiev result order popcorn movi theater larg popcor...
# 1     road trip time fell asleep said honey got wake sleepi need talk said asleep just rest eye air throat whi mouth open mile start chew becaus gummi b...
# 2     mention girl alreadi theyr theyr stepdaught stepdad stepdad took leas coupl girl year thank veri step parent ani broken home ahead abl come step s...
# 3     cooper love old bo love old bum forev cuz boat let know enjoy captain ship wa hurrican onli time save boat harbor know pickit lot pressur steppar ...
# 4     girl teenag got coupl teenag home theyr realli embrac everi time tell peopl teenag daughter home theyr alway like aha good luck realli tough just ...
# ...                                                                                                                                                     ...
# 2835  let forget let forget ive met cosbi defend let just rememb ha valuabl legaci just throw away rememb black man win emmi televis rememb guy make car...
# 2836  ahah ahah everi ghetto ahah ahah ahah everi ghetto ahah ahah ahah everi ghetto ahah ahah ahah everi ghetto wait wait wait wait wait forgot fourth ...
# 2837  ahah ahah everi ghetto ahah revolut ahah ahah ahah everi ghetto thing befor just want acknowledg real comedi fan acknowledg lost fuck juggernaut c...
# 2838  kick ye kick ye kick ye gone kick tribe flow layer right phife poem sayer time studio conveyor mr dinkin pleas mayor youll realli big favor boy th...
# 2839  kick ye kick ye kick ye gone kick tribe flow layer right phife poem sayer time studio conveyor mr dinkin pleas mayor youll realli big favor boy th...
#
# [2840 rows x 2 columns]

# %%
merge_transcripts(clean_corpus, 'keywords_clean.xlsx')
# Out:
# Extracting...: 100%|███████████████████████████████████████████████████████████████████| 40/40 [09:42<00:00, 14.55s/it]
#                 Comedian  \
# 0            amy schumer
# 1          andy woodhull
# 2           arsenio hall
# 3            aziz ansari
# 4         bert kreischer
# 5              bill burr
# 6           chris d’elia
# 7             chris rock
# 8         dave chappelle
# 9             eric andre
# 10          george lopez
# 11         hannah gadsby
# 12          hasan minhaj
# 13      iliza shlesinger
# 14        jack whitehall
# 15        jerry seinfeld
# 16         jim jefferies
# 17         jimmy o. yang
# 18                jo koy
# 19             joe rogan
# 20       kenny sebastian
# 21            kevin hart
# 22            marc maron
# 23          mark normand
# 24      michael mcintyre
# 25         michelle wolf
# 26          neal brennan
# 27         patton oswalt
# 28         pete davidson
# 29          ramy youssef
# 30          ronny chieng
# 31          roy wood jr.
# 32        russell peters
# 33  sebastian maniscalco
# 34       tiffany haddish
# 35            tom segura
# 36           trevor noah
# 37        urzila carlson
# 38               vir das
# 39      whitney cummings
#
#                                                                                                                                                  Keywords
# 0   right peopl hand wa like okay fuck, thi, guy, dont, theyr, um, think, caus, oh, place question everyon know, love, time, becaus, alway want, got, ...
# 1   thi, like, want, know, thing, late everyth time wife wa, think gon na, goe dont, snake, theyr, shower said whi, becaus, stuff kid, home, come, gir...
# 2   know wa, shit, fuck, motherfuck, thi, like gave, got, said, black dont, right, hi, love, use, look smile, phone, caus thought saw, want, ye, oh, s...
# 3   excus thi, thing, seen stuff gener like video, bottl wa happen, realli, know problem, think, fuck, look, say, situat peopl, littl kid, okay, caus ...
# 4   goe, wa, room peopl like dont, got, way thi, wife, right, want, fuck dick, dad, think, start, didnt know, ila, men look, come, walk, oh, mom, day ...
# 5   right thi, like realli, wa, know ani, come, la, non penso, fuckin, becom fuck everyth goddamn, le, prima squadra di, guy, una cosa, che hanno dovu...
# 6   fuck, dont, wa, right thi awesom, alway drunk time like, girl, dude, say, look, hey know excus, yo, shit, love, caus, way, real, thing, relax okay...
# 7   shit, like, suck fuck, dont, peopl, man drug, right hour, smoke crack got hi job want know wa, say, check thi, look, make, white, good, love, talk...
# 8   ens, wa fuck cooki, dejar la, una, lo mismo, hora que, said, got, nobodi els, man, di, al, por, thi black guy broke, know job, time, motherfuck, n...
# 9   wa, fuck, right, stole thi, day like smoke, know, hi, shit, man legal, guy want, got weed, oh, start, dont look eat, littl, went, parent, text, th...
# 10  run famili didnt come fuck, know, dont, like, right, wa, peopl, said, look, thi countri latino, theyr, listen, want talk, love, kid, hey, got ta, ...
# 11  wa, like, look thi, thing, joke, know way tell peopl, ive, good, fuck expect, stori, men, dont need problem, think, nanett right clear isnt whi be...
# 12  thi, wa, dont understand like, say, dad, time, know hey didnt, peopl, bolsonaro, hi, got, love, presid, brazil, year, right thing let, tonight wan...
# 13  like, thi, fuck, want, girl, right, thing wa, way okay know women feel, hi, love, gon na, think, got marri, hate becaus, theyr, exhaust dont energ...
# 14  wa, ive got, look, hi, royal famili like, time, come, doesnt ani prestigi thi quit, becaus, say, littl, know bad, need, jack oh, want sir, fuck mi...
# 15  thi, like, dont, wa, know, think, peopl, come, say, good thing, guy, right, work, look, want, life, ticket got, littl stori, leav whi, car, time, ...
# 16  fuck, thi, like use, thing, becaus, hi, think, rightli wrongli, come littl, tell stori right, open beer son wa time look went, ive, fucken, di, la...
# 17  wa, like hey, dont know, got say, asian, mans, guy veri come, right, beauti peopl thi great man, american, dad, chines, time, kid, good year, want...
# 18  like, fuck, mom, right, want, oh shit, son, got everi, dont think, thi whi love come home, tonight know, hi, talk, kid, say, becaus, dad, look man...
# 19  oh fuck, like let make thi happen, right, know, come dont, think, happi peopl, shit, theyr, onli way wa, kid, look, whi, cat, time, okay, world li...
# 20  like, thi, guy, come, wa, okay, hey, mom, bro music, oh, thing, use danc best becaus dont care, let make, maid, warm nice, whi, say veri, want, lo...
# 21  got, like, said, come man fuck, place thi crazi wa, right, look, dont nobodi, time, act shit, son bitch, babi, ass, goddamn, kid, caus hi, tell, w...
# 22  like, think, right happi came realli dont know, ago wa, say, jesu, guy look, happen, peopl, gon na tri got thi weird thing head sort, man, littl, ...
# 23  wa, like whoo realli, hey right, dude dont, hung isnt amaz know, peopl want kid, great crowd ye thank guy come, time, good, someth say, make, ladi...
# 24  wa, dont, think, ive, said, caus, fuck, need, face id look, thing, quit, know realli happen wouldnt, oh, money come, love, actual veri, phone, bit...
# 25  think, like thing okay bad, dont, women, want, know someon, thi strong, caus, men hear, veri, talk, say, make, look phone wa, tri, good, man, righ...
# 26  like wear, wa, got peopl, think, dont, thing, know person, say want, caus, right, becaus, thi point, guy young, women, white, day, girl, come, the...
# 27  die like, happen wa, guy, hi, got, thi bit right love, dont, gon na, way, peopl, thing, let, ah know turn, come, everyon okay oh pace, said, ha, s...
# 28  like, wa, thi, right guy, dont, gon know fade, caus, fuck, okay, veri thank, time, fuckin, dad, goe, come, oh guess got, dick, think, tell, shit, ...
# 29  wa, thi dude like think, dont know, becaus, realli, fuck, got, man, peopl, look, feel, love, whi, happen someon, make, someth, sex, dad, come, mea...
# 30  like, okay, becaus, america, make peopl fuck, dont, time, second let start right, wa, thi point, wed, everi year, train, know, come, wife, want, t...
# 31  thi, wa, dont, man, time, real aint, dude like, white peopl, got figur way, gon na know, come, shit, day, tri, black folk, mcdonald, want, think, ...
# 32  like dont thing, thi, right, fuck, happen know sound, shit, white peopl, oh, look, good home mean wa born, got fat, caus, kid, want becaus stop, r...
# 33  right, work like, got said, dont, youll thi, peopl, theyr, gon na say, think wa famili, hous, start, come towel hi shoulder, littl, talk foreign o...
# 34  like, wa, thi, right, got, said, dont know hava, fuck whi, cuz, littl, tri, tiffani say gon na make, start, let parti, talk, bad look, shit friend...
# 35  know, like gon na hard, dont want fuck, peopl, guy right, man, goe play kick, thing, shit thank, alon hous wa, whi, suppos thi dead, caus theyr, l...
# 36  whi wa, know say, right, like favorit experi dont live great wonder becaus, thi fun, thing peopl hate, man, time, got, want, black, realli, oh loo...
# 37  know, fuck, look, feel like want, peopl love australia caus, open becaus dont, come, youv, oh, sometim right, wa, loser, guy thi whi, ive got, shi...
# 38  thi, shit, wa arm, theyr like smart, fuck, look, guy, got, come, beauti, ye okay becaus know realiti right, english think, india, went, ha, stupid...
# 39  know, feel like littl, think, thought wa, women come, say fuck, oh becaus, shit, look, make, use work thi guy everi day hed run, dont understand, ...
